# %%
# Import dependencies
import pandas as pd #For importing data and data munging
import numpy as np
import seaborn as sns # for data visualization
from sklearn.linear_model import LinearRegression as LinReg #For predective modeling
import datetime as dt #To work with datetime
import pandas_datareader as pdr #To read and import data from web
import matplotlib.pyplot as plt # For data visualization
from matplotlib import style # To choose from styles from matplotlib
style.use('ggplot')
# %matplotlib inline

# %%
# Set start and end dates
start = dt.datetime(2010, 1, 1)
end = dt.datetime(2015, 1, 1)

# %%
# Import data from web using pandas datareader and save it in a variable
apple = pdr.get_data_yahoo('AAPL', start=start, end=end)
microsoft = pdr.get_data_yahoo('MSFT', start=start, end=end)
amazon = pdr.get_data_yahoo('AMZN', start=start, end=end)
sony = pdr.get_data_yahoo('SNE', start=start, end=end)
google = pdr.get_data_yahoo('GOOG', start=start, end=end)
facebook = pdr.get_data_yahoo('FB', start=start, end=end)

# %%
# Below I create a DataFrame consisting of the adjusted closing price of imported stocks.
stocks = pd.DataFrame({"AAPL": apple["Adj Close"],
                      "MSFT": microsoft["Adj Close"],
                      "AMZN": amazon["Adj Close"],
                      "SNE": sony["Adj Close"],
                      "GOOG": google["Adj Close"]}, index=None)

# %%
stocks.head()#To see the first five rows in stocks dataframe
# Out:
#                  AAPL        AMZN        GOOG       MSFT        SNE
# Date
# 2010-01-04  27.727039  133.899994  313.062468  25.555485  30.020000
# 2010-01-05  27.774976  134.690002  311.683844  25.563741  29.879999
# 2010-01-06  27.333178  132.250000  303.826685  25.406859  29.850000
# 2010-01-07  27.282650  130.000000  296.753749  25.142634  29.799999
# 2010-01-08  27.464034  133.520004  300.709808  25.316031  30.410000

# %%
stocks.tail() #To see the last 5 rows in stocks column
# Out:
#                   AAPL        AMZN        GOOG       MSFT        SNE
# Date
# 2014-12-24  107.271380  303.029999  528.772422  45.337706  21.320000
# 2014-12-26  109.167611  309.089996  534.032392  45.092843  21.270000
# 2014-12-29  109.091001  312.040009  530.332426  44.687873  21.170000
# 2014-12-30  107.759799  310.299988  530.422394  44.282904  20.580000
# 2014-12-31  105.710333  310.350006  526.402397  43.746085  20.469999

# %%
stocks.shape
# Out:
# (1833, 5)

# %%
stocks.index #To see the index of stocks df
# Out:
# DatetimeIndex(['2010-01-04', '2010-01-05', '2010-01-06', '2010-01-07',
#                '2010-01-08', '2010-01-11', '2010-01-12', '2010-01-13',
#                '2010-01-14', '2010-01-15',
#                ...
#                '2017-03-31', '2017-04-03', '2017-04-04', '2017-04-05',
#                '2017-04-06', '2017-04-07', '2017-04-10', '2017-04-11',
#                '2017-04-12', '2017-04-13'],
#               dtype='datetime64[ns]', name='Date', length=1833, freq=None)

# %%
stocks.columns #To see the column names in stocks df
# Out:
# Index(['AAPL', 'AMZN', 'GOOG', 'MSFT', 'SNE'], dtype='object')

# %%
stocks.values #To see the values of columns in stocks df
# Out:
# array([[  27.727039,  133.899994,  313.062468,   25.555485,   30.02    ],
#        [  27.774976,  134.690002,  311.683844,   25.563741,   29.879999],
#        [  27.333178,  132.25    ,  303.826685,   25.406859,   29.85    ],
#        ...,
#        [ 141.630005,  902.359985,  823.349976,   65.480003,   31.85    ],
#        [ 141.800003,  896.22998 ,  824.320007,   65.230003,   31.48    ],
#        [ 141.050003,  884.669983,  823.559998,   64.949997,   31.32    ]])

# %%
stocks_2 = stocks.loc[:, ["AAPL", "AMZN", "GOOG", "MSFT"]] #Selected AAPL and MSFT columns using .loc 
stocks_2.head()                            #and stored them in new variable
# Out:
#                  AAPL        AMZN        GOOG       MSFT
# Date
# 2010-01-04  27.727039  133.899994  313.062468  25.555485
# 2010-01-05  27.774976  134.690002  311.683844  25.563741
# 2010-01-06  27.333178  132.250000  303.826685  25.406859
# 2010-01-07  27.282650  130.000000  296.753749  25.142634
# 2010-01-08  27.464034  133.520004  300.709808  25.316031

# %%
times = pd.DatetimeIndex(stocks_2.index)
stcks_grpd = stocks_2.groupby([times.year]).mean()
#stocks_3= grouped_raw.reset_index() #Resetting the index
#stocks_3.rename(columns={'index':'Date'})
stcks_grpd.head()


#grouped_raw.head()
# Out:
#            AAPL        AMZN        GOOG       MSFT
# 2010  33.665072  139.140397  267.544462  22.555294
# 2011  47.160237  196.672024  284.203368  22.237127
# 2012  74.813837  220.303640  321.087703  26.149729
# 2013  62.617988  298.031588  441.680447  29.379392
# 2014  87.635833  332.551033  561.342392  39.499515

# %%
apple.head() #To see the first 5 rows in apple df
apple_adj=apple.loc[:,["Adj Close"]]
#google_close=google.loc[:,["Close"]]
apple_adj.head()
#google_close.head()
# Out:
#                  Close
# Date
# 2010-01-04  626.751061
# 2010-01-05  623.991055
# 2010-01-06  608.261023
# 2010-01-07  594.101005
# 2010-01-08  602.021036

# %%
apple.tail() #see last 5 rows in apple df
# Out:
#                   Open        High         Low       Close    Volume  \
# Date
# 2017-04-07  143.729996  144.179993  143.270004  143.339996  16621300
# 2017-04-10  143.600006  143.880005  142.899994  143.169998  18473000
# 2017-04-11  142.940002  143.350006  140.059998  141.630005  30275300
# 2017-04-12  141.600006  142.149994  141.009995  141.800003  20238900
# 2017-04-13  141.910004  142.380005  141.050003  141.050003  17652900
#
#              Adj Close
# Date
# 2017-04-07  143.339996
# 2017-04-10  143.169998
# 2017-04-11  141.630005
# 2017-04-12  141.800003
# 2017-04-13  141.050003

# %%
apple.tail(10)#see last 10 rows in apple df
apple.shape
# Out:
# (1833, 6)

# %%
concat_aapl_msft.head()
concat_aapl_msft.shape
#concat_aapl_msft= pd.concat([apple, microsoft]) #concatinating the the values in two different df's
# Out:
# (3666, 6)

# %%
stocks.plot(figsize=(10,7)) #plot the stocks df

# %%
stocks.plot(secondary_y = ["MSFT"], grid=True, figsize=(10,7))

# %%
sns.barplot(x='FinYear', y='Amount', data=invYr)

# %%
plt.scatter(stcks_grpd.index, stcks_grpd['AAPL'])

# %%
stocks.describe()
microsoft.describe()
# Out:
#               Open         High          Low        Close        Volume  \
# count  1833.000000  1833.000000  1833.000000  1833.000000  1.833000e+03
# mean     38.162537    38.488222    37.838396    38.180889  4.487933e+07
# std      11.813074    11.886018    11.746748    11.824227  2.428843e+07
# min      23.090000    23.320000    22.730000    23.010000  8.409600e+06
# 25%      27.920000    28.110001    27.719999    27.930000  2.864270e+07
# 50%      34.230000    34.490002    33.889999    34.209999  3.967390e+07
# 75%      46.830002    47.349998    46.480000    46.889999  5.433090e+07
# max      66.300003    66.349998    65.480003    65.860001  3.193179e+08
#
#          Adj Close
# count  1833.000000
# mean     35.268046
# std      12.937744
# min      19.174388
# 25%      23.979141
# 50%      31.014462
# 75%      44.544210
# max      65.860001

# %%
stocks.mean()
apple_adj.mean()
google_close.mean()
# Out:
# Close    673.683167
# dtype: float64

# %%
stocks.median()
apple_adj.median()
google_close.median()
# Out:
# Close    619.54108
# dtype: float64

# %%
stocks.std()
apple_adj.std()
google_close.std()
# Out:
# Close    159.47386
# dtype: float64

# %%
stocks.apply(np.cumsum)
# Or apply your own function, such as ﬁnding the spread (max value - min value):
stocks.apply(lambda x: x.max() - x.min())

apple_adj.apply(np.cumsum)
apple_adj.apply(lambda x: x.max() - x.min())

#google_close.apply(np.cumsum)
#google_close.apply(lambda x: x.max() - x.min())
# Out:
# Adj Close    119.888092
# dtype: float64

# %%
LinReg(stocks.head())
#LinReg(apple_adj.head())
# Out:
# LinearRegression(copy_X=True,
#          fit_intercept=                 AAPL        AMZN        GOOG       MSFT        SNE
# Date
# 2010-01-04  27.727039  133.899994  313.062468  25.555485  30.020000
# 2010-01-05  27.774976  134.690002  311.683844  25.563741  29.879999
# 2010-01-06  27.333178  132.250000  303.826685  25.406859  29.850000
# 2010-01-07  27.282650  130.000000  296.753749  25.142634  29.799999
# 2010-01-08  27.464034  133.520004  300.709808  25.316031  30.410000,
#          n_jobs=1, normalize=False)

# %%
np.corrcoef(stocks)[1, 4]
# Out:
# 0.99993414881842846

# %%
sns.pairplot(stocks, x_vars='AAPL', y_vars='MSFT', size=10, kind='reg')

# %%
#sns.stripplot(x="MSFT", y="AAPL", data=stocks_3, hue_order = ["AAPL", "MSFT"])

# %%
times = pd.DatetimeIndex(stocks.index)
#grouped_raw = stocks.groupby([times.year])
grouped = stocks.groupby([times.year]).mean()

# %%
#grouped_raw.head()
grouped.head()
# Out:
#            AAPL        AMZN        GOOG       MSFT        SNE
# 2010  33.665072  139.140397  267.544462  22.555294  32.661706
# 2011  47.160237  196.672024  284.203368  22.237127  25.810397
# 2012  74.813837  220.303640  321.087703  26.149729  14.495560
# 2013  62.617988  298.031588  441.680447  29.379392  18.299603
# 2014  87.635833  332.551033  561.342392  39.499515  18.074762

# %%
plt.figure(figsize= (15,5))
plt.plot(grouped['SNE'])
plt.title("Adj closing of SNE")
plt.xlabel("year")
plt.ylabel("Adj Closing price")
plt.show()

# %%
x = grouped.index.values.reshape(-1, 1)
y = grouped['MSFT'].values

# %%
reg = LinReg()
reg.fit(x,y)
y_pred = reg.predict(x)
ci=reg.score(x,y) #to calculate the confidence interval, which corresponds with the standard error of the estimate
print("Accuracy: " + str(ci))
# Out:
# Accuracy: 0.93762478258

# %%
plt.figure(figsize = (15, 5))
plt.title('Linear Regression')
plt.scatter(x=x, y=y_pred)
plt.scatter(x=x, y=y, c="r")
plt.plot(x, reg.predict(x), color='r',
         linewidth=1)
plt.gca()

# %%
reg.predict(2020)
# Out:
# array([ 77.8081128])

# %%
sns.regplot(x=x, y=y, color="r", ci=ci, scatter=True)

# %%
sns.pairplot(stocks,  x_vars=["MSFT","AAPL","AMZN"] , y_vars='GOOG', aspect=0.7, size=10, kind='reg')
